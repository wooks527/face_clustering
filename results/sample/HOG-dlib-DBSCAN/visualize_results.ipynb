# %% [markdown]
# # Visualize Face Clustering Results

# %% [markdown]
# ## Load Clustering Results

# %%
from matplotlib import pyplot as plt
import json
import cv2

# %%
with open("clustered_results.json", "r") as f:
    cluster_info = json.load(f)
cluster_info.keys(), cluster_info[list(cluster_info.keys())[0]][:3]
# Out:
# (dict_keys(['-1', '0', '1', '2', '3', '4', '5', '6']), [[290], [638], [696]])

# %% [markdown]
# ## Visualize Results

# %% [markdown]
# ### Original Video
#
# - [https://www.youtube.com/watch?v=bUQj7Ng7PCs](https://www.youtube.com/watch?v=bUQj7Ng7PCs)

# %% [markdown]
# ### Clustering Results

# %%
def display_results(cluster_id, scenes):
    print(f"ID-{cluster_id}:")
    for scene_id, frame_ids in enumerate(scenes):
        print(f"Scene-{scene_id}:")
        print(f"Frame-{frame_ids[0]} to Frame-{frame_ids[-1]}:")
        rows, cols = 1, max(len(frame_ids), 5)
        fig = plt.figure(figsize=(8, 8))
        for i, frame_id in enumerate(frame_ids):
            fig.add_subplot(rows, cols, i+1)
            img_path = f"clustered_imgs/fid-{cluster_id}-{scene_id}-{frame_id}.jpg"
            img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
            plt.xticks([])
            plt.yticks([])
            plt.imshow(img)
        plt.show()

# %% [markdown]
# #### Clustered Images
#
# - 중간에 인식하지 못해 같은 구간에 나오는 사람인데 다른 구간으로 나누어진 경우가 많음
# - 사람 얼굴이 아닌데 얼굴로 인식한 경우가 있음

# %%
for cluster_id, scenes in cluster_info.items():
    if cluster_id != "-1":
        display_results(cluster_id, scenes)
# Out:
# ID-0:
# Scene-0:
# Frame-1595 to Frame-1711:
# Scene-1:
# Frame-1769 to Frame-1827:
# Scene-2:
# Frame-1943 to Frame-2059:
# Scene-3:
# Frame-2291 to Frame-2378:
# Scene-4:
# Frame-2697 to Frame-2697:
# Scene-5:
# Frame-2813 to Frame-2813:
# Scene-6:
# Frame-2958 to Frame-2987:
# Scene-7:
# Frame-3190 to Frame-3219:
# Scene-8:
# Frame-3422 to Frame-3538:
# Scene-9:
# Frame-3770 to Frame-3770:
# Scene-10:
# Frame-3828 to Frame-3828:
# Scene-11:
# Frame-4118 to Frame-4118:
# Scene-12:
# Frame-4176 to Frame-4176:
# Scene-13:
# Frame-4234 to Frame-4234:
# Scene-14:
# Frame-4466 to Frame-4466:
# Scene-15:
# Frame-4524 to Frame-4524:
# Scene-16:
# Frame-4582 to Frame-4582:
# Scene-17:
# Frame-5162 to Frame-5162:
# Scene-18:
# Frame-5336 to Frame-5336:
# Scene-19:
# Frame-5800 to Frame-5800:
# ID-1:
# Scene-0:
# Frame-638 to Frame-638:
# Scene-1:
# Frame-1276 to Frame-1305:
# Scene-2:
# Frame-1479 to Frame-1479:
# ID-2:
# Scene-0:
# Frame-2001 to Frame-2001:
# Scene-1:
# Frame-2146 to Frame-2146:
# Scene-2:
# Frame-2233 to Frame-2233:
# Scene-3:
# Frame-2349 to Frame-2378:
# Scene-4:
# Frame-2697 to Frame-2697:
# ID-3:
# Scene-0:
# Frame-2204 to Frame-2204:
# Scene-1:
# Frame-2900 to Frame-2929:
# Scene-2:
# Frame-3016 to Frame-3132:
# Scene-3:
# Frame-3248 to Frame-3248:
# Scene-4:
# Frame-3306 to Frame-3393:
# Scene-5:
# Frame-3596 to Frame-3596:
# Scene-6:
# Frame-3654 to Frame-3654:
# Scene-7:
# Frame-3712 to Frame-3712:
# Scene-8:
# Frame-3886 to Frame-3886:
# Scene-9:
# Frame-4002 to Frame-4002:
# Scene-10:
# Frame-4060 to Frame-4060:
# Scene-11:
# Frame-4292 to Frame-4292:
# Scene-12:
# Frame-5220 to Frame-5220:
# Scene-13:
# Frame-5278 to Frame-5278:
# Scene-14:
# Frame-5394 to Frame-5394:
# Scene-15:
# Frame-5452 to Frame-5452:
# Scene-16:
# Frame-5626 to Frame-5626:
# Scene-17:
# Frame-6032 to Frame-6032:
# Scene-18:
# Frame-6496 to Frame-6496:
# ID-4:
# Scene-0:
# Frame-3422 to Frame-3451:
# Scene-1:
# Frame-4234 to Frame-4234:
# Scene-2:
# Frame-4350 to Frame-4350:
# Scene-3:
# Frame-4408 to Frame-4408:
# Scene-4:
# Frame-4466 to Frame-4466:
# ID-5:
# Scene-0:
# Frame-3422 to Frame-3422:
# Scene-1:
# Frame-3480 to Frame-3538:
# Scene-2:
# Frame-4118 to Frame-4118:
# Scene-3:
# Frame-4176 to Frame-4176:
# ID-6:
# Scene-0:
# Frame-580 to Frame-580:
# Scene-1:
# Frame-725 to Frame-725:
# Scene-2:
# Frame-1276 to Frame-1276:
# Scene-3:
# Frame-3161 to Frame-3161:

# %% [markdown]
# #### Not-Clustered Images
#
# - 눈으로 봤을 때는 Cluster를 만들 수 있는 경우인데 Cluster 형성이 안된 이미지가 꽤 있음

# %%
for cluster_id, scenes in cluster_info.items():
    if cluster_id == "-1":
        display_results(cluster_id, scenes)
# Out:
# ID--1:
# Scene-0:
# Frame-290 to Frame-290:
# Scene-1:
# Frame-638 to Frame-638:
# Scene-2:
# Frame-696 to Frame-696:
# Scene-3:
# Frame-754 to Frame-841:
# Scene-4:
# Frame-928 to Frame-957:
# Scene-5:
# Frame-1044 to Frame-1102:
# Scene-6:
# Frame-1218 to Frame-1218:
# Scene-7:
# Frame-1305 to Frame-1305:
# Scene-8:
# Frame-1508 to Frame-1508:
# Scene-9:
# Frame-1798 to Frame-1827:
# Scene-10:
# Frame-2001 to Frame-2001:
# Scene-11:
# Frame-2001 to Frame-2001:
# Scene-12:
# Frame-2291 to Frame-2291:
# Scene-13:
# Frame-2639 to Frame-2639:
# Scene-14:
# Frame-2697 to Frame-2697:
# Scene-15:
# Frame-2697 to Frame-2697:
# Scene-16:
# Frame-2813 to Frame-2813:
# Scene-17:
# Frame-2987 to Frame-2987:
# Scene-18:
# Frame-2987 to Frame-2987:
# Scene-19:
# Frame-3161 to Frame-3190:
# Scene-20:
# Frame-3422 to Frame-3451:
# Scene-21:
# Frame-3509 to Frame-3509:
# Scene-22:
# Frame-3509 to Frame-3538:
# Scene-23:
# Frame-3654 to Frame-3654:
# Scene-24:
# Frame-3770 to Frame-3770:
# Scene-25:
# Frame-4118 to Frame-4118:
# Scene-26:
# Frame-4350 to Frame-4350:
# Scene-27:
# Frame-4408 to Frame-4408:
# Scene-28:
# Frame-4524 to Frame-4524:
# Scene-29:
# Frame-4698 to Frame-4698:
# Scene-30:
# Frame-4756 to Frame-4756:
# Scene-31:
# Frame-4814 to Frame-4814:

# %% [markdown]
# #### 추가 의견
#
# - 얼굴이 인식되지 않은 결과에 대해서는 위 Visualization으로 알 수 없음
